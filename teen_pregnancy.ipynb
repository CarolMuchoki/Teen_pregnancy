# %%
import pandas as pd
import numpy as np
df= pd.read_csv('teen.csv')
df.describe()
# Out:
#           REF_DATE  DGUID      UOM_ID  SCALAR_ID         VALUE  STATUS  \
# count   960.000000    0.0  960.000000      960.0    960.000000     0.0
# mean   1999.025000    NaN  244.500000        0.0   1018.092188     NaN
# std       0.821631    NaN   21.511207        0.0   3596.042522     NaN
# min    1998.000000    NaN  223.000000        0.0      0.000000     NaN
# 25%    1998.000000    NaN  223.000000        0.0     13.700000     NaN
# 50%    1999.000000    NaN  244.500000        0.0     39.850000     NaN
# 75%    2000.000000    NaN  266.000000        0.0    271.750000     NaN
# max    2000.000000    NaN  266.000000        0.0  41588.000000     NaN
#
#          DECIMALS
# count  960.000000
# mean     0.500000
# std      0.500261
# min      0.000000
# 25%      0.000000
# 50%      0.500000
# 75%      1.000000
# max      1.000000

# %%
df.isnull()
# Out:
#      REF_DATE    GEO  DGUID  Age group  Teen pregnancy outcomes  \
# 0       False  False   True      False                    False
# 1       False  False   True      False                    False
# 2       False  False   True      False                    False
# 3       False  False   True      False                    False
# 4       False  False   True      False                    False
# ..        ...    ...    ...        ...                      ...
# 955     False  False   True      False                    False
# 956     False  False   True      False                    False
# 957     False  False   True      False                    False
# 958     False  False   True      False                    False
# 959     False  False   True      False                    False
#
#      Characteristics    UOM  UOM_ID  SCALAR_FACTOR  SCALAR_ID  VECTOR  \
# 0              False  False   False          False      False   False
# ...

# %%
df.isnull().sum()
# Out:
# REF_DATE                     0
# GEO                          0
# DGUID                      960
# Age group                    0
# Teen pregnancy outcomes      0
# Characteristics              0
# UOM                          0
# UOM_ID                       0
# SCALAR_FACTOR                0
# SCALAR_ID                    0
# VECTOR                       0
# COORDINATE                   0
# VALUE                        0
# STATUS                     960
# SYMBOL                     957
# TERMINATED                 912
# DECIMALS                     0
# dtype: int64

# %%
df.dropna (how= 'all', inplace = True, axis= 1)
df
# Out:
#      REF_DATE      GEO       Age group  Teen pregnancy outcomes  \
# 0        1998   Canada  15 to 19 years  Total, teen pregnancies
# 1        1998   Canada  15 to 19 years  Total, teen pregnancies
# 2        1998   Canada  15 to 19 years              Live births
# 3        1998   Canada  15 to 19 years              Live births
# 4        1998   Canada  15 to 19 years        Induced abortions
# ..        ...      ...             ...                      ...
# 955      2000  Nunavut  18 to 19 years              Live births
# 956      2000  Nunavut  18 to 19 years        Induced abortions
# 957      2000  Nunavut  18 to 19 years        Induced abortions
# 958      2000  Nunavut  18 to 19 years               Fetal loss
# 959      2000  Nunavut  18 to 19 years               Fetal loss
#
#             Characteristics                      UOM  UOM_ID SCALAR_FACTOR  \
# 0          Number of events                   Number     223        units
# ...

# %%
df.drop_duplicates()
# Out:
#      REF_DATE      GEO       Age group  Teen pregnancy outcomes  \
# 0        1998   Canada  15 to 19 years  Total, teen pregnancies
# 1        1998   Canada  15 to 19 years  Total, teen pregnancies
# 2        1998   Canada  15 to 19 years              Live births
# 3        1998   Canada  15 to 19 years              Live births
# 4        1998   Canada  15 to 19 years        Induced abortions
# ..        ...      ...             ...                      ...
# 955      2000  Nunavut  18 to 19 years              Live births
# 956      2000  Nunavut  18 to 19 years        Induced abortions
# 957      2000  Nunavut  18 to 19 years        Induced abortions
# 958      2000  Nunavut  18 to 19 years               Fetal loss
# 959      2000  Nunavut  18 to 19 years               Fetal loss
#
#             Characteristics                      UOM  UOM_ID SCALAR_FACTOR  \
# 0          Number of events                   Number     223        units
# ...
